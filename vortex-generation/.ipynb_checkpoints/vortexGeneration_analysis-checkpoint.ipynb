# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import scipy.optimize

# %% [markdown]
# # 1. Basic function declaration

# %%
#Class to create an HTML table with some data - original from Yves Dubief
class ListTable(list):
    def _repr_html_(self):
        html = ["<table>"]
        for row in self:
            html.append("<tr>")
            
            for col in row:
                html.append("<td>{0}</td>".format(col))
            
            html.append("</tr>")
        html.append("</table>")
        return ''.join(html)

# %% [markdown]
# # 2. Inlet perturbation BC to force oscillation vortex sheding

# %%
y = np.linspace(-1,1,250)
t = np.linspace(0,100,250)

Y, T = np.meshgrid(y, t)

Z = 1+2*np.exp(-((T-20)**2)/(0.025)-((Y-1)**2)/(1.5))

fig = plt.figure(figsize=(11,7), dpi=100)
ax = fig.gca(projection='3d')
surf = ax.plot_surface(T, Y, Z, rstride = 1, cstride = 1, cmap = cm.viridis, linewidth = 0, antialiased = False)
ax.set_xlabel('$t$')
ax.set_ylabel('$y$')
ax.set_zlabel('$V$')
ax.set_zlim([0,3])
ax.set_title('Inlet Velocity BC')
# Out:
# Text(0.5,0.92,'Inlet Velocity BC')

# %% [markdown]
# # 3. Vortex shedding analysis

# %% [markdown]
# ## 3.1. Joint of all timestep PlotOverLine files

# %% [markdown]
# (if a serie of <tt> timestep </tt> values are in the folder, to join them in just one big matrix, make the next cell of type Code - i.e.<tt> Y </tt> over the cell - and execute it)

# %% [raw]
# timesteps = 200
# a_b = 'b'
#
# #header in this case is: p, Ux, Uy, Uz, vtkPoint, arclength, X, Y, Z
# values = np.zeros((timesteps, np.shape(np.genfromtxt('0%s.csv' %(a_b), delimiter=',', skip_header=1))[0], np.shape(np.genfromtxt('0%s.csv' %(a_b), delimiter=',', skip_header=1))[1]))
#
# for i in range(timesteps):
#     values[i,:,:] = np.genfromtxt('%i%s.csv' %(i, a_b), delimiter=',', skip_header=1)
#
# if a_b == 'a':
#     np.save('above.npy', values)
# if a_b == 'b':
#     np.save('below.npy', values)

# %% [markdown]
# ## 3.2. Analysis

# %%
above = np.load('above.npy')
below = np.load('below.npy')
#The matrix characterization is: [time, line, paraFoam_header]

# %% [markdown]
# ## 3.3. 3D representation

# %%
timesteps = 200

# %%
lineLengthA = above[0,:,5] #line length 
timeA = np.linspace(0, timesteps, timesteps)

LLa, TSa = np.meshgrid(lineLengthA, timeA)

pressureFieldA = np.array([above[0,:,0]])

for i in range(1, np.shape(above)[0]):
    pressureFieldA = np.append(pressureFieldA, [above[i,:,0]], axis=0)
    
fig = plt.figure(figsize=(11,7), dpi=100)
ax = fig.gca(projection='3d')
surf = ax.plot_surface(TSa, LLa, pressureFieldA, rstride = 1, cstride = 1, cmap = cm.viridis, linewidth = 0, antialiased = False)
ax.set_xlabel('Timestep')
ax.set_ylabel('Line length')
ax.set_zlabel('$Pressure$')
ax.set_zlim([-1,1])
ax.set_title('Pressure Field Above cylinder')
# Out:
# Text(0.5,0.92,'Pressure Field Above cylinder')

# %%
lineLengthB = above[0,:,5]
timeB = np.linspace(0, timesteps, timesteps) 

LLb, TSb = np.meshgrid(lineLengthB, timeB)

pressureFieldB = np.array([below[0,:,0]])

for i in range(1, np.shape(above)[0]):
    pressureFieldB = np.append(pressureFieldB, [below[i,:,0]], axis=0)
    
fig = plt.figure(figsize=(11,7), dpi=100)
ax = fig.gca(projection='3d')
surf = ax.plot_surface(TSb, LLb, pressureFieldB, rstride = 1, cstride = 1, cmap = cm.viridis, linewidth = 0, antialiased = False)
ax.set_xlabel('Timestep')
ax.set_ylabel('Line length')
ax.set_zlabel('$Pressure$')
ax.set_zlim([-1,1])
ax.set_title('Pressure Field Above cylinder')
# Out:
# Text(0.5,0.92,'Pressure Field Above cylinder')

# %%
lineLengthA = above[0,:,5] #line length 
timeA = np.linspace(0, timesteps, timesteps)

LLa, TSa = np.meshgrid(lineLengthA, timeA)

pressureFieldA = np.array([above[0,:,0]])

for i in range(1, np.shape(above)[0]):
    pressureFieldA = np.append(pressureFieldA, [above[i,:,0]], axis=0)
    
fig = plt.figure(figsize=(11,7), dpi=100)
ax = fig.gca(projection='3d')
surf = ax.plot_surface(TSa, LLa, pressureFieldA, rstride = 1, cstride = 1, cmap = cm.viridis, linewidth = 0, antialiased = False)
ax.set_xlabel('Timestep')
ax.set_ylabel('Line length')
ax.set_zlabel('$Pressure$')
ax.set_zlim([-1,1])
ax.set_title('Pressure Field Above cylinder')
ax.view_init(90, 0)

# %% [markdown]
# ## 3.4. 2D representation

# %% [raw]
# #old BC computation
#
# peaks = np.array([34.5019,40.0039,45.4977,51.0048,56.5053,62.0035,67.5011,72.9983,78.4951,84.0032,89.4989,95.0044])
#
# increment = peaks[1:] - peaks[0:-1]
#
# vst = peaks[0]                        #vortex shedding time
# frequency = np.mean(1/increment)      #vortex shedding frequency
#
# AFCv = (1+np.tanh(((t)+t*np.sin(2*np.pi*frequency*t))-2*vst))*np.cos(45)
#
# fig = plt.figure(figsize=(7,5), dpi=100)
# ax = fig.gca()
# ax.plot(t, AFCv)
# ax.set_xlabel('$t$')
# ax.set_ylabel('$V$')
# ax.set_title('AFC velocity BC')
#
# print(peaks[0])
# print(frequency)

# %%
f, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(6, sharex=True, figsize=(17,20), dpi=100)

ax1.plot(np.linspace(0, timesteps, timesteps), above[:,np.abs(above[0,:,5]-2).argmin(),0], 'r', label='x = 2 (above)')
ax1.plot(np.linspace(0, timesteps, timesteps), below[:,np.abs(below[0,:,5]-2).argmin(),0], 'r--', label='x = 2 (below)')
ax1.set_ylabel('Pressure')
ax1.set_xlim([0,200])
ax1.set_title('Pressure variations along different $x$ axis cuts')

ax2.plot(np.linspace(0, timesteps, timesteps), above[:,np.abs(above[0,:,5]-4).argmin(),0], 'g', label='x = 4 (above)')
ax2.plot(np.linspace(0, timesteps, timesteps), below[:,np.abs(below[0,:,5]-4).argmin(),0], 'g--', label='x = 4 (below)')
ax2.set_xlim([0,200])
ax2.set_ylabel('Pressure')

ax3.plot(np.linspace(0, timesteps, timesteps), above[:,np.abs(above[0,:,5]-6).argmin(),0], 'b', label='x = 6 (above)')
ax3.plot(np.linspace(0, timesteps, timesteps), below[:,np.abs(below[0,:,5]-6).argmin(),0], 'b--', label='x = 6 (below)')
ax3.set_xlim([0,200])
ax3.set_ylabel('Pressure')

ax4.plot(np.linspace(0, timesteps, timesteps), above[:,np.abs(above[0,:,5]-8).argmin(),0], 'y', label='x = 8 (above)')
ax4.plot(np.linspace(0, timesteps, timesteps), below[:,np.abs(below[0,:,5]-8).argmin(),0], 'y--', label='x = 8 (below)')
ax4.set_xlim([0,200])
ax4.set_ylabel('Pressure')

ax5.plot(np.linspace(0, timesteps, timesteps), above[:,np.abs(above[0,:,5]-10).argmin(),0], 'k', label='x = 10 (above)')
ax5.plot(np.linspace(0, timesteps, timesteps), below[:,np.abs(below[0,:,5]-10).argmin(),0], 'k--', label='x = 10 (below)')
ax5.set_xlim([0,200])
ax5.set_ylabel('Pressure')

ax6.plot(np.linspace(0, timesteps, timesteps), above[:,np.abs(above[0,:,5]-12).argmin(),0], 'c', label='x = 12 (above)')
ax6.plot(np.linspace(0, timesteps, timesteps), below[:,np.abs(below[0,:,5]-12).argmin(),0], 'c--', label='x = 12 (below)')
ax6.set_xlim([0,200])
ax6.set_ylabel('Pressure')
ax6.set_xlabel('$t$')

ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()
ax5.legend()
ax6.legend()

# %% [markdown]
# ## 3.5. Wave interpolation and calculations

# %% [raw]
# http://scipy-cookbook.readthedocs.io/items/FittingData.html

# %% [raw]
# t = np.linspace(100, 200, 100)
# y = above100[:,100]
#
# freq = np.fft.fftfreq(len(t), (t[1]-t[0])) #np.fft.fftfreq(window_size, step_size) - return sample freqs
# fty = abs(np.fft.fft(y)) #np.fft.fft(data) - returns the transformed data
# guess = [2.*np.pi*np.abs(freq[np.argmax(fty.real[1:])]), np.sqrt(2)*np.std(y), 0.0, np.mean(y)] #Guess values: amplitude, freq, phase, offset
#                                                                                                               #    frequency: excluding the zero frequency "peak", take one frequency
#                                                                                                               #    amplitude: standard deviation of the data
#                                                                                                               #    phase: let's begin with zero
#                                                                                                               #    offset: mean value of the data
# p1 = optimize.leastsq(costFunc, guess[:], args=(t, y))
#
#
#
#
# def sineFunc(values, time): #values= 0-amplitude, 1-omega, 2-phase, 3-offset
#     return values[0]*np.sin(values[1]*time + values[2]) + values[3]
#
# def costFunc(values, time, realV):
#     return sineFunc(values, time) - realV
#
#
#
#
#
# def sine_fit (t, y):
#     freq = np.fft.fftfreq(len(t), (t[1]-t[0])) #np.fft.fftfreq(window_size, step_size) - return sample freqs
#     fty = abs(np.fft.fft(y)) #np.fft.fft(data) - returns the transformed data
#     guess = [np.sqrt(2)*np.std(y), 2*np.pi*np.abs(freq[np.argmax(fty.real[1:])]), 0.0, np.mean(y)] #Initial guess values: amplitude, freq, phase, offset
#                                                                                                               #    frequency: excluding the zero frequency "peak", take one frequency
#                                                                                                               #    amplitude: standard deviation of the data
#                                                                                                               #    phase: let's begin with zero
#                                                                                                               #    offset: mean value of the data
#
#     print(guess)
#     fitfunc = lambda p, x: p[0]*np.sin(p[1]*x+p[2]) + p[3] # Target function
#     errfunc = lambda p, x, y: fitfunc(p, x) - y # Distance to the target function
#     p1, success = optimize.leastsq(errfunc, guess[:], args=(t, y))
#     print(p1)
#     return p1

# %%
# Generate data points with noise
Tx = np.linspace(100, 200, 100)
tX = above100[:,80]

# %%
# Fit the first set
fitfunc = lambda p, x: p[0]*np.cos(2*np.pi/p[1]*x+p[2]) + p[3] # Target function
errfunc = lambda p, x, y: fitfunc(p, x) - y # Distance to the target function

p1a = np.zeros((4,np.shape(above100)[1]))
p1b = np.zeros((4,np.shape(below100)[1]))

for i in range(np.shape(above100)[1]):
    tX = above100[:,i]
    p0 = [np.sqrt(2)*np.std(tX), 11, 0., np.mean(tX)] # Initial guess for the parameters
    p1a[:,i], success = scipy.optimize.leastsq(errfunc, p0[:], args=(Tx, tX))

for i in range(np.shape(below100)[1]):
    tX = below100[:,i]
    p0 = [np.sqrt(2)*np.std(tX), 11, 0., np.mean(tX)] # Initial guess for the parameters
    p1b[:,i], success = scipy.optimize.leastsq(errfunc, p0[:], args=(Tx, tX))

    
tX = above100[:,825]
    
plt.plot(Tx, tX, "ro", Tx, fitfunc(p1[:,825], Tx), "r-") # Plot of the data and the fit

# Legend the plot
plt.title("Oscillations in the compressed trap")
plt.xlabel("time [ms]")
plt.ylabel("displacement [um]")
plt.legend(('x position', 'x fit', 'y position', 'y fit'))
plt.show()

# %%
np.shape(p1)
# Out:
# (4, 1001)

# %%
#plt.plot(np.linspace(0,1001,1001),abs(p1[0,:]))
plt.plot(np.linspace(0,1001,1001),p1[1,:])
#plt.plot(np.linspace(0,1001,1001),abs(p1[2,:]))
#plt.plot(np.linspace(0,1001,1001),p1[3,:])

# %%
fig, ax = plt.subplots(nrows=6, ncols=2, sharex=True, figsize=(17,20), dpi=100)

plt.subplot(6, 2, 1)
plt.plot(np.linspace(0, timesteps, timesteps), above[:,np.abs(above[0,:,5]-2).argmin(),0], 'r.', label='x = 2')
plt.plot(np.linspace(100,200,100),fitfunc(p1a[:,np.abs(above[0,:,5]-2).argmin()], np.linspace(100,200,100)), 'k-', label='Curve-fit')
plt.xlim([100,200])
plt.title('Above streamline')
plt.legend()

plt.subplot(6, 2, 2)
plt.plot(np.linspace(0, timesteps, timesteps), below[:,np.abs(below[0,:,5]-2).argmin(),0], 'r.', label='x = 2')
plt.plot(np.linspace(100,200,100),fitfunc(p1b[:,np.abs(below[0,:,5]-2).argmin()], np.linspace(100,200,100)), 'k-', label='Curve-fit')
plt.xlim([100,200])
plt.title('Below streamline')
plt.legend()

xCuttingPoint = np.array([4,6,8,10,12])
color = ['g','b','y','k','c']

for i in range(0,5):   
    plt.subplot(6, 2, 3+2*i)
    plt.plot(np.linspace(0, timesteps, timesteps), above[:,np.abs(above[0,:,5]-xCuttingPoint[i]).argmin(),0], '.', color=color[i], label='x = %i' %xCuttingPoint[i])
    plt.plot(np.linspace(100,200,100),fitfunc(p1a[:,np.abs(above[0,:,5]-xCuttingPoint[i]).argmin()], np.linspace(100,200,100)), 'k-', label='Curve-fit')
    plt.xlim([100,200])
    plt.legend()

    plt.subplot(6, 2, 4+2*i)
    plt.plot(np.linspace(0, timesteps, timesteps), below[:,np.abs(below[0,:,5]-xCuttingPoint[i]).argmin(),0], '.', color=color[i], label='x = %i' %xCuttingPoint[i])
    plt.plot(np.linspace(100,200,100),fitfunc(p1b[:,np.abs(below[0,:,5]-xCuttingPoint[i]).argmin()], np.linspace(100,200,100)), 'k-', label='Curve-fit')
    plt.xlim([100,200])
    plt.legend()
